# %% [markdown]
# # Transformers, what can they do?

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# %pip install datasets evaluate 'transformers[sentencepiece]'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /Users/usama/Library/Python/3.9/lib/python/site-packages (4.0.0)
# Requirement already satisfied: evaluate in /Users/usama/Library/Python/3.9/lib/python/site-packages (0.4.5)
# Requirement already satisfied: transformers[sentencepiece] in /Users/usama/Library/Python/3.9/lib/python/site-packages (4.57.1)
# Requirement already satisfied: pandas in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (2.3.2)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: xxhash in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: numpy>=1.17 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: fsspec[http]<=2025.3.0,>=2023.1.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (2025.3.0)
# Requirement already satisfied: packaging in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (25.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (0.34.4)
# Requirement already satisfied: filelock in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: requests>=2.32.2 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from transformers[sentencepiece]) (2025.7.34)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from transformers[sentencepiece]) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from transformers[sentencepiece]) (0.6.2)
# Requirement already satisfied: protobuf in /Users/usama/Library/Python/3.9/lib/python/site-packages (from transformers[sentencepiece]) (6.32.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from transformers[sentencepiece]) (0.2.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
torch.set_default_device("cpu")

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", device="cpu")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9598051905632019}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598051905632019},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification", model="MoritzLaurer/mDeBERTa-v3-base-xnli-multilingual-nli-2mil7", device="cpu")
# Provide a list of sentences to classify
sentences_to_classify = [
    "میں کولاب کے ذریعے ٹرانسفارمرز لائبریری کے بارے میں سیکھ رہا ہوں", # This is the original Urdu sentence
    "I am learning about transformers library through colab", # English
    "我透過 colab 學習緊變壓器庫" ,# google translate to chinese
    "The new political debate is about to begin.",
    "My company's new product launch is next month."
]
classifier(
    sentences_to_classify,
    candidate_labels=["education", "politics", "business"],
)
# Out:
# Device set to use cpu
# [{'sequence': 'میں کولاب کے ذریعے ٹرانسفارمرز لائبریری کے بارے میں سیکھ رہا ہوں',
#   'labels': ['education', 'business', 'politics'],
#   'scores': [0.6931171417236328, 0.19838754832744598, 0.10849529504776001]},
#  {'sequence': 'I am learning about transformers library through colab',
#   'labels': ['education', 'business', 'politics'],
#   'scores': [0.9587868452072144, 0.028601573780179024, 0.012611563317477703]},
#  {'sequence': '我透過 colab 學習緊變壓器庫',
#   'labels': ['education', 'business', 'politics'],
#   'scores': [0.9661048650741577, 0.019467206671833992, 0.014427999965846539]},
#  {'sequence': 'The new political debate is about to begin.',
#   'labels': ['politics', 'business', 'education'],
#   'scores': [0.9880924224853516, 0.008811429142951965, 0.0030961246229708195]},
#  {'sequence': "My company's new product launch is next month.",
#   'labels': ['business', 'politics', 'education'],
#   'scores': [0.975993812084198, 0.014134136959910393, 0.009872037917375565]}]

# %%
from transformers import pipeline

generator = pipeline("text-generation",device="cpu")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to get started with JavaScript and get up to speed with JavaScript.\n\nWe will also show you how to create a Node.js application using the Node.js SDK.\n\nThe course includes:\n\nThe first part of the course will teach you how to create and use a Node.js application running in the browser.\n\nThe second part of the course will allow you to create a website using the Node.js SDK.\n\nThe third part of the course will guide you through the steps of setting up your business.\n\nOur course will cover:\n\nThe technical implementation and features of JavaScript\n\nThe functional aspects of JavaScript\n\nThe usage of JavaScript in JavaScript contexts\n\nThe usage of JavaScript in JavaScript contexts How to write a website using Node.js\n\nThe course is divided into two parts:\n\nThe first part of the course teaches you how to create and use a JavaScript application using the Node.js SDK.\n\nThe second part of the course teaches you how to create and use a Node.js application using the Node.js SDK.\n\nThe course also covers:\n\nThe development of an application using Node.js\n\nThe development of an application using Node.js The development of a web app using'}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2", device="cpu")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to read the English language.\n\n\n\nWe will talk about reading the English language in general.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nThe English language is a complex language.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English language in particular.\nWe will talk about the English'},
#  {'generated_text': 'In this course, we will teach you how to perform the following exercises:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask", device="cpu")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.1961977481842041,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.040527213364839554,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True, device="cpu")
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'entity_group': 'PER',
#   'score': np.float32(0.9981694),
#   'word': 'Sylvain',
#   'start': 11,
#   'end': 18},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.97960204),
#   'word': 'Hugging Face',
#   'start': 33,
#   'end': 45},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9932106),
#   'word': 'Brooklyn',
#   'start': 49,
#   'end': 57}]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering", device="cpu")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# {'score': 0.6949767470359802, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
# %pip install --upgrade torch
# Out:
# 1247.16s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /Users/usama/Library/Python/3.9/lib/python/site-packages (2.4.1)
# Collecting torch
#   Using cached torch-2.8.0-cp39-none-macosx_11_0_arm64.whl (73.6 MB)
# Requirement already satisfied: fsspec in /Users/usama/Library/Python/3.9/lib/python/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: networkx in /Users/usama/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from torch) (4.14.1)
# Requirement already satisfied: filelock in /Users/usama/Library/Python/3.9/lib/python/site-packages (from torch) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from torch) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/usama/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1
#     Uninstalling torch-2.4.1:
#       Successfully uninstalled torch-2.4.1
# Successfully installed torch-2.8.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline

summarizer = pipeline("summarization", device="cpu")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of
    graduates in traditional engineering disciplines such as mechanical, civil,
    electrical, chemical, and aeronautical engineering declined, but in most of
    the premier American universities engineering curricula now concentrate on
    and encourage largely the study of engineering science. As a result, there
    are declining offerings in engineering subjects dealing with infrastructure,
    the environment, and related issues, and greater concentration on high
    technology subjects, largely supporting increasingly complex scientific
    developments. While the latter is important, it should not be at the expense
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other
    industrial countries in Europe and Asia, continue to encourage and advance
    the teaching of engineering. Both China and India, respectively, graduate
    six and eight times as many traditional engineers as does the United States.
    Other industrial countries at minimum maintain their output, while America
    suffers an increasingly serious decline in the number of engineering graduates
    and a lack of well-educated engineers.
"""
)
# Out:
# /Users/usama/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# [{'summary_text': ' The number of engineering graduates in the United States has declined in recent years . China and India graduate six and eight times as many traditional engineers as the U.S. does . Rapidly developing economies such as China continue to encourage and advance the teaching of engineering . There are declining offerings in engineering subjects dealing with infrastructure, infrastructure, the environment, and related issues .'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en", device="cpu")
translator("Ce cours est produit par Hugging Face.")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /Users/usama/Library/Python/3.9/lib/python/site-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu
# [{'translation_text': 'This course is produced by Hugging Face.'}]
